# %%
import pandas as pd

# %%
df=pd.read_csv('/content/StudentPerformance - Sheet1.csv')

# %%
df1=df
df2=df1
df3=df
df4=df

# %%
df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0       M          65           62.0             60             66.0
# 1       F          62           78.0             71             65.0
# 2       M          64           60.0             70             68.0
# 3       F          67           69.0             74             65.0
# 4       M          68           76.0             69             70.0
# 5       F          90           65.0             77             76.0
# 6       M          79           62.0             80             67.0
# 7       F          75           72.0             72             65.0
# 8       M          61           74.0             70             69.0
# 9       F          73           68.0             92             63.0
# 10      M          74           64.0             70             60.0
# 11      F          75           67.0             80             65.0
# 12      M          65           77.0             77             77.0
# 13      M          70           63.0             77             79.0
# 14      M          60            NaN             79             77.0
# 15      F          70           76.0             66             98.0
# 16      F          63           72.0             63             62.0
# 17      F          66           77.0             67             78.0
# 18      F          94           75.0             67             66.0
# 19      M          62           79.0             68             60.0
# 20      F          67           62.0             64             61.0
# 21      M          64           95.0             72              NaN
# 22      F          61           70.0             96             72.0
# 23      M          74           74.0             75             68.0
# 24      F          79           68.0             75             67.0
# 25      M          62           75.0             60             69.0
# 26      F          67           71.0             72             64.0
# 27      M          68           78.0             64             77.0
# 28      F          72           62.0             77             69.0
#
#     club join year  placement offer count
# 0           2018.0                      1
# 1           2018.0                      1
# 2           2020.0                      1
# 3           2021.0                      1
# 4           2019.0                      1
# 5           2020.0                      2
# 6           2021.0                      1
# 7           2021.0                      1
# 8           2018.0                      1
# 9           2018.0                      1
# 10          2020.0                      1
# 11          2020.0                      1
# 12          2019.0                      2
# 13          2018.0                      2
# 14          2018.0                      2
# 15          2019.0                      3
# 16          2021.0                      1
# 17             NaN                      2
# 18          2021.0                      1
# 19          2020.0                      1
# 20          2020.0                      1
# 21          2019.0                      1
# 22          2018.0                      1
# 23          2019.0                      1
# 24          2020.0                      1
# 25          2019.0                      1
# 26          2021.0                      1
# 27          2018.0                      2
# 28          2018.0                      1

# %%
df.isnull()
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0    False       False          False          False            False
# 1    False       False          False          False            False
# 2    False       False          False          False            False
# 3    False       False          False          False            False
# 4    False       False          False          False            False
# 5    False       False          False          False            False
# 6    False       False          False          False            False
# 7    False       False          False          False            False
# 8    False       False          False          False            False
# 9    False       False          False          False            False
# 10   False       False          False          False            False
# 11   False       False          False          False            False
# 12   False       False          False          False            False
# 13   False       False          False          False            False
# 14   False       False           True          False            False
# 15   False       False          False          False            False
# 16   False       False          False          False            False
# 17   False       False          False          False            False
# 18   False       False          False          False            False
# 19   False       False          False          False            False
# 20   False       False          False          False            False
# 21   False       False          False          False             True
# 22   False       False          False          False            False
# 23   False       False          False          False            False
# 24   False       False          False          False            False
# 25   False       False          False          False            False
# 26   False       False          False          False            False
# 27   False       False          False          False            False
# 28   False       False          False          False            False
#
#     club join year  placement offer count
# 0            False                  False
# 1            False                  False
# 2            False                  False
# 3            False                  False
# 4            False                  False
# 5            False                  False
# 6            False                  False
# 7            False                  False
# 8            False                  False
# 9            False                  False
# 10           False                  False
# 11           False                  False
# 12           False                  False
# 13           False                  False
# 14           False                  False
# 15           False                  False
# 16           False                  False
# 17            True                  False
# 18           False                  False
# 19           False                  False
# 20           False                  False
# 21           False                  False
# 22           False                  False
# 23           False                  False
# 24           False                  False
# 25           False                  False
# 26           False                  False
# 27           False                  False
# 28           False                  False

# %%
df.isnull().sum()
# Out:
# gender                   0
# math score               0
# reading score            1
# writing score            0
# placement score          1
# club join year           1
# placement offer count    0
# dtype: int64

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

# %%
df['gender']=le.fit_transform(df['gender'])
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        1          65           62.0             60             66.0
# 1        0          62           78.0             71             65.0
# 2        1          64           60.0             70             68.0
# 3        0          67           69.0             74             65.0
# 4        1          68           76.0             69             70.0
# 5        0          90           65.0             77             76.0
# 6        1          79           62.0             80             67.0
# 7        0          75           72.0             72             65.0
# 8        1          61           74.0             70             69.0
# 9        0          73           68.0             92             63.0
# 10       1          74           64.0             70             60.0
# 11       0          75           67.0             80             65.0
# 12       1          65           77.0             77             77.0
# 13       1          70           63.0             77             79.0
# 14       1          60            NaN             79             77.0
# 15       0          70           76.0             66             98.0
# 16       0          63           72.0             63             62.0
# 17       0          66           77.0             67             78.0
# 18       0          94           75.0             67             66.0
# 19       1          62           79.0             68             60.0
# 20       0          67           62.0             64             61.0
# 21       1          64           95.0             72              NaN
# 22       0          61           70.0             96             72.0
# 23       1          74           74.0             75             68.0
# 24       0          79           68.0             75             67.0
# 25       1          62           75.0             60             69.0
# 26       0          67           71.0             72             64.0
# 27       1          68           78.0             64             77.0
# 28       0          72           62.0             77             69.0
#
#     club join year  placement offer count
# 0           2018.0                      1
# 1           2018.0                      1
# 2           2020.0                      1
# 3           2021.0                      1
# 4           2019.0                      1
# 5           2020.0                      2
# 6           2021.0                      1
# 7           2021.0                      1
# 8           2018.0                      1
# 9           2018.0                      1
# 10          2020.0                      1
# 11          2020.0                      1
# 12          2019.0                      2
# 13          2018.0                      2
# 14          2018.0                      2
# 15          2019.0                      3
# 16          2021.0                      1
# 17             NaN                      2
# 18          2021.0                      1
# 19          2020.0                      1
# 20          2020.0                      1
# 21          2019.0                      1
# 22          2018.0                      1
# 23          2019.0                      1
# 24          2020.0                      1
# 25          2019.0                      1
# 26          2021.0                      1
# 27          2018.0                      2
# 28          2018.0                      1

# %%
df.columns
# Out:
# Index(['gender', 'math score', 'reading score', 'writing score',
#        'placement score', 'club join year', 'placement offer count'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# gender                   0
# math score               0
# reading score            1
# writing score            0
# placement score          1
# club join year           1
# placement offer count    0
# dtype: int64

# %%
df.describe()
# Out:
#           gender  math score  reading score  writing score  placement score  \
# count  29.000000   29.000000      28.000000      29.000000        28.000000
# mean    0.482759   69.551724      71.107143      72.551724        69.392857
# std     0.508548    8.244419       7.563750       8.209690         7.927165
# min     0.000000   60.000000      60.000000      60.000000        60.000000
# 25%     0.000000   64.000000      64.750000      67.000000        65.000000
# 50%     0.000000   67.000000      71.500000      72.000000        67.500000
# 75%     1.000000   74.000000      76.000000      77.000000        73.000000
# max     1.000000   94.000000      95.000000      96.000000        98.000000
#
#        club join year  placement offer count
# count       28.000000              29.000000
# mean      2019.357143               1.275862
# std          1.161553               0.527565
# min       2018.000000               1.000000
# 25%       2018.000000               1.000000
# 50%       2019.000000               1.000000
# 75%       2020.000000               1.000000
# max       2021.000000               3.000000

# %%
df['reading score']
# Out:
# 0     62.0
# 1     78.0
# 2     60.0
# 3     69.0
# 4     76.0
# 5     65.0
# 6     62.0
# 7     72.0
# 8     74.0
# 9     68.0
# 10    64.0
# 11    67.0
# 12    77.0
# 13    63.0
# 14     NaN
# 15    76.0
# 16    72.0
# 17    77.0
# 18    75.0
# 19    79.0
# 20    62.0
# 21    95.0
# 22    70.0
# 23    74.0
# 24    68.0
# 25    75.0
# 26    71.0
# 27    78.0
# 28    62.0
# Name: reading score, dtype: float64

# %%
df[df['reading score'].isnull()].index.tolist()
# Out:
# [14]

# %%
df['reading score']=df['reading score'].fillna(60)

# %%
df['reading score']
# Out:
# 0     62.0
# 1     78.0
# 2     60.0
# 3     69.0
# 4     76.0
# 5     65.0
# 6     62.0
# 7     72.0
# 8     74.0
# 9     68.0
# 10    64.0
# 11    67.0
# 12    77.0
# 13    63.0
# 14    60.0
# 15    76.0
# 16    72.0
# 17    77.0
# 18    75.0
# 19    79.0
# 20    62.0
# 21    95.0
# 22    70.0
# 23    74.0
# 24    68.0
# 25    75.0
# 26    71.0
# 27    78.0
# 28    62.0
# Name: reading score, dtype: float64

# %%
df['reading score'].notnull().sum()
# Out:
# 29

# %%
df[df['math score'].isnull()].index.tolist()
# Out:
# []

# %%
df['math score']=df['math score'].fillna(df['math score'].mean())

# %%
df['math score'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# gender                   0
# math score               0
# reading score            0
# writing score            0
# placement score          1
# club join year           1
# placement offer count    0
# dtype: int64

# %%
df[df['writing score'].isnull()].index.tolist()
# Out:
# []

# %%
df['writing score']=df['writing score'].fillna(df['writing score'].median())

# %%
df['writing score'].isnull().sum()
# Out:
# 0

# %%
df2.head()
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0       1          65           62.0             60             66.0
# 1       0          62           78.0             71             65.0
# 2       1          64           60.0             70             68.0
# 3       0          67           69.0             74             65.0
# 4       1          68           76.0             69             70.0
#
#    club join year  placement offer count
# 0          2018.0                      1
# 1          2018.0                      1
# 2          2020.0                      1
# 3          2021.0                      1
# 4          2019.0                      1

# %%
import numpy as np

# %%
df.isnull().sum()
# Out:
# gender                   0
# math score               0
# reading score            0
# writing score            0
# placement score          1
# club join year           1
# placement offer count    0
# dtype: int64

# %%
df[df['math score'].isnull()].index.tolist()
# Out:
# []

# %%
df[df['reading score'].isnull()].index.tolist()
# Out:
# []

# %%
df.replace(to_replace=np.nan,value=80)
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        1          65           62.0             60             66.0
# 1        0          62           78.0             71             65.0
# 2        1          64           60.0             70             68.0
# 3        0          67           69.0             74             65.0
# 4        1          68           76.0             69             70.0
# 5        0          90           65.0             77             76.0
# 6        1          79           62.0             80             67.0
# 7        0          75           72.0             72             65.0
# 8        1          61           74.0             70             69.0
# 9        0          73           68.0             92             63.0
# 10       1          74           64.0             70             60.0
# 11       0          75           67.0             80             65.0
# 12       1          65           77.0             77             77.0
# 13       1          70           63.0             77             79.0
# 14       1          60           60.0             79             77.0
# 15       0          70           76.0             66             98.0
# 16       0          63           72.0             63             62.0
# 17       0          66           77.0             67             78.0
# 18       0          94           75.0             67             66.0
# 19       1          62           79.0             68             60.0
# 20       0          67           62.0             64             61.0
# 21       1          64           95.0             72             80.0
# 22       0          61           70.0             96             72.0
# 23       1          74           74.0             75             68.0
# 24       0          79           68.0             75             67.0
# 25       1          62           75.0             60             69.0
# 26       0          67           71.0             72             64.0
# 27       1          68           78.0             64             77.0
# 28       0          72           62.0             77             69.0
#
#     club join year  placement offer count
# 0           2018.0                      1
# 1           2018.0                      1
# 2           2020.0                      1
# 3           2021.0                      1
# 4           2019.0                      1
# 5           2020.0                      2
# 6           2021.0                      1
# 7           2021.0                      1
# 8           2018.0                      1
# 9           2018.0                      1
# 10          2020.0                      1
# 11          2020.0                      1
# 12          2019.0                      2
# 13          2018.0                      2
# 14          2018.0                      2
# 15          2019.0                      3
# 16          2021.0                      1
# 17            80.0                      2
# 18          2021.0                      1
# 19          2020.0                      1
# 20          2020.0                      1
# 21          2019.0                      1
# 22          2018.0                      1
# 23          2019.0                      1
# 24          2020.0                      1
# 25          2019.0                      1
# 26          2021.0                      1
# 27          2018.0                      2
# 28          2018.0                      1

# %%
df2.isnull().sum()
# Out:
# gender                   0
# math score               0
# reading score            0
# writing score            0
# placement score          1
# club join year           1
# placement offer count    0
# dtype: int64

# %% [markdown]
# ###Deleting null values using dropna() metthod

# %%
df3.isnull().sum()
# Out:
# gender                   0
# math score               0
# reading score            0
# writing score            0
# placement score          1
# club join year           1
# placement offer count    0
# dtype: int64

# %%
df3[df3['math score'].isnull()].index.tolist()
# Out:
# []

# %%
df3[df3['reading score'].isnull()].index.tolist()
# Out:
# []

# %%
#To drop rows with at least 1 null value
df3.dropna()
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        1          65           62.0             60             66.0
# 1        0          62           78.0             71             65.0
# 2        1          64           60.0             70             68.0
# 3        0          67           69.0             74             65.0
# 4        1          68           76.0             69             70.0
# 5        0          90           65.0             77             76.0
# 6        1          79           62.0             80             67.0
# 7        0          75           72.0             72             65.0
# 8        1          61           74.0             70             69.0
# 9        0          73           68.0             92             63.0
# 10       1          74           64.0             70             60.0
# 11       0          75           67.0             80             65.0
# 12       1          65           77.0             77             77.0
# 13       1          70           63.0             77             79.0
# 14       1          60           60.0             79             77.0
# 15       0          70           76.0             66             98.0
# 16       0          63           72.0             63             62.0
# 18       0          94           75.0             67             66.0
# 19       1          62           79.0             68             60.0
# 20       0          67           62.0             64             61.0
# 22       0          61           70.0             96             72.0
# 23       1          74           74.0             75             68.0
# 24       0          79           68.0             75             67.0
# 25       1          62           75.0             60             69.0
# 26       0          67           71.0             72             64.0
# 27       1          68           78.0             64             77.0
# 28       0          72           62.0             77             69.0
#
#     club join year  placement offer count
# 0           2018.0                      1
# 1           2018.0                      1
# 2           2020.0                      1
# 3           2021.0                      1
# 4           2019.0                      1
# 5           2020.0                      2
# 6           2021.0                      1
# 7           2021.0                      1
# 8           2018.0                      1
# 9           2018.0                      1
# 10          2020.0                      1
# 11          2020.0                      1
# 12          2019.0                      2
# 13          2018.0                      2
# 14          2018.0                      2
# 15          2019.0                      3
# 16          2021.0                      1
# 18          2021.0                      1
# 19          2020.0                      1
# 20          2020.0                      1
# 22          2018.0                      1
# 23          2019.0                      1
# 24          2020.0                      1
# 25          2019.0                      1
# 26          2021.0                      1
# 27          2018.0                      2
# 28          2018.0                      1

# %%
#To Drop columns with at least 1 null value
df4.dropna(axis=1)
# Out:
#     gender  math score  reading score  writing score  placement offer count
# 0        1          65           62.0             60                      1
# 1        0          62           78.0             71                      1
# 2        1          64           60.0             70                      1
# 3        0          67           69.0             74                      1
# 4        1          68           76.0             69                      1
# 5        0          90           65.0             77                      2
# 6        1          79           62.0             80                      1
# 7        0          75           72.0             72                      1
# 8        1          61           74.0             70                      1
# 9        0          73           68.0             92                      1
# 10       1          74           64.0             70                      1
# 11       0          75           67.0             80                      1
# 12       1          65           77.0             77                      2
# 13       1          70           63.0             77                      2
# 14       1          60           60.0             79                      2
# 15       0          70           76.0             66                      3
# 16       0          63           72.0             63                      1
# 17       0          66           77.0             67                      2
# 18       0          94           75.0             67                      1
# 19       1          62           79.0             68                      1
# 20       0          67           62.0             64                      1
# 21       1          64           95.0             72                      1
# 22       0          61           70.0             96                      1
# 23       1          74           74.0             75                      1
# 24       0          79           68.0             75                      1
# 25       1          62           75.0             60                      1
# 26       0          67           71.0             72                      1
# 27       1          68           78.0             64                      2
# 28       0          72           62.0             77                      1

# %% [markdown]
# ## **Handling** **Outliers**
# ### **1.Detecting outliers using Boxplot:**

# %%
df.columns
# Out:
# Index(['gender', 'math score', 'reading score', 'writing score',
#        'placement score', 'club join year', 'placement offer count'],
#       dtype='object')

# %%
col=['gender', 'math score', 'reading score', 'writing score',
       'placement score', 'club join year', 'placement offer count']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(10,7))
df.boxplot(col)
# Out:
# <AxesSubplot:>

# %%
for column in df:
  plt.figure()
  df.boxplot([column])

# %%
import seaborn as sns

# %%
for column in df:
  plt.figure(figsize=(7,5))
  sns.boxplot(data=df,y=column)

# %%
print(np.where(df['math score']>80))
# Out:
# (array([ 5, 18]),)

# %%
print(np.where(df['reading score']>90))
# Out:
# (array([21]),)

# %%
print(np.where(df['writing score']<40))
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ## **2.Detecting Outliers using Scatterplot:**

# %%
#ax = plt.subplots(figsize = (18,10))
plt.scatter(df['math score'], df['placement offer count'])
plt.show()

# %%
df.columns
# Out:
# Index(['gender', 'math score', 'reading score', 'writing score',
#        'placement score', 'club join year', 'placement offer count'],
#       dtype='object')

# %%
plt.scatter(df['placement offer count'],df['placement offer count'],c='yellow',linewidths = 2,marker = '.',edgecolor ='red' ,s = 50)
plt.xlabel=("placement score")
plt.ylabel=("placement offer count")
plt.show()

# %%
plt.scatter(x=df['math score'],y=df['placement score'],c='blue',linewidths = 2,marker ='^',edgecolor = 'green',s = 80)
plt.show()

# %%
plt.figure()
df.plot.scatter(x ='placement score' ,y = 'placement offer count', c ='gender', alpha = 0.4,cmap = plt.get_cmap('jet'),colorbar= 'red' )
#plt.savefig('scatter plot.png')
#plt.tight_Layout()
plt.show()

# %% [markdown]
# **3**.Detecting outliers using Z-SCORE:

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math score']))
z
# Out:
# 0     0.561870
# 1     0.932193
# 2     0.685311
# 3     0.314988
# 4     0.191547
# 5     2.524159
# 6     1.166306
# 7     0.672541
# 8     1.055635
# 9     0.425659
# 10    0.549100
# 11    0.672541
# 12    0.561870
# 13    0.055336
# 14    1.179076
# 15    0.055336
# 16    0.808752
# 17    0.438429
# 18    3.017923
# 19    0.932193
# 20    0.314988
# 21    0.685311
# 22    1.055635
# 23    0.549100
# 24    1.166306
# 25    0.932193
# 26    0.314988
# 27    0.191547
# 28    0.302218
# Name: math score, dtype: float64

# %%
threshold =1.8
sample_outliers = np.where(z >threshold)
sample_outliers
# Out:
# (array([ 5, 18]),)

# %%
df['math score']
# Out:
# 0     65
# 1     62
# 2     64
# 3     67
# 4     68
# 5     90
# 6     79
# 7     75
# 8     61
# 9     73
# 10    74
# 11    75
# 12    65
# 13    70
# 14    60
# 15    70
# 16    63
# 17    66
# 18    94
# 19    62
# 20    67
# 21    64
# 22    61
# 23    74
# 24    79
# 25    62
# 26    67
# 27    68
# 28    72
# Name: math score, dtype: int64

# %% [markdown]
# ## **Detecting outliers using Inter Quantile Range(IQR):**
# IQR = Quartile3 - Quartile1
# To define the outlier base value is defined above and below datasets normal range namely Upper and Lower bounds, define the
# upper and the lower bound (1.5*IQR value is considered) :
#
# upper = Q3 +1.5*IQR
#
# lower = Q1 -1.5*IQR

# %%
sorted_rscore= sorted(df['reading score'])
sorted_rscore
# Out:
# [60.0,
#  60.0,
#  62.0,
#  62.0,
#  62.0,
#  62.0,
#  63.0,
#  64.0,
#  65.0,
#  67.0,
#  68.0,
#  68.0,
#  69.0,
#  70.0,
#  71.0,
#  72.0,
#  72.0,
#  74.0,
#  74.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  79.0,
#  95.0]

# %%
# Calculate and print Quartile 1 and Quartile 3
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 64.0 76.0

# %%
IQR = q3-q1
IQR
# Out:
# 12.0

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 46.0 94.0

# %%
#print outliers
r_outliers = []
for i in sorted_rscore:
  if (i<lwr_bound or i>upr_bound):
    r_outliers.append(i)
    print(r_outliers)
# Out:
# [95.0]

# %%
df['reading score']
# Out:
# 0     62.0
# 1     78.0
# 2     60.0
# 3     69.0
# 4     76.0
# 5     65.0
# 6     62.0
# 7     72.0
# 8     74.0
# 9     68.0
# 10    64.0
# 11    67.0
# 12    77.0
# 13    63.0
# 14    60.0
# 15    76.0
# 16    72.0
# 17    77.0
# 18    75.0
# 19    79.0
# 20    62.0
# 21    95.0
# 22    70.0
# 23    74.0
# 24    68.0
# 25    75.0
# 26    71.0
# 27    78.0
# 28    62.0
# Name: reading score, dtype: float64

# %% [markdown]
# # # Handling of Outliers:

# %% [markdown]
# ## **1.Trimming\removing the outliers:**

# %%
new_df=df.copy()
for i in sample_outliers:
  new_df.drop(i,inplace=True)
  new_df

# %% [markdown]
# ## **2.Quantile based flooring and capping**

# %%
df_stud=df.copy()

# %%
df_stud
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        1          65           62.0             60             66.0
# 1        0          62           78.0             71             65.0
# 2        1          64           60.0             70             68.0
# 3        0          67           69.0             74             65.0
# 4        1          68           76.0             69             70.0
# 5        0          90           65.0             77             76.0
# 6        1          79           62.0             80             67.0
# 7        0          75           72.0             72             65.0
# 8        1          61           74.0             70             69.0
# 9        0          73           68.0             92             63.0
# 10       1          74           64.0             70             60.0
# 11       0          75           67.0             80             65.0
# 12       1          65           77.0             77             77.0
# 13       1          70           63.0             77             79.0
# 14       1          60           60.0             79             77.0
# 15       0          70           76.0             66             98.0
# 16       0          63           72.0             63             62.0
# 17       0          66           77.0             67             78.0
# 18       0          94           75.0             67             66.0
# 19       1          62           79.0             68             60.0
# 20       0          67           62.0             64             61.0
# 21       1          64           95.0             72              NaN
# 22       0          61           70.0             96             72.0
# 23       1          74           74.0             75             68.0
# 24       0          79           68.0             75             67.0
# 25       1          62           75.0             60             69.0
# 26       0          67           71.0             72             64.0
# 27       1          68           78.0             64             77.0
# 28       0          72           62.0             77             69.0
#
#     club join year  placement offer count
# 0           2018.0                      1
# 1           2018.0                      1
# 2           2020.0                      1
# 3           2021.0                      1
# 4           2019.0                      1
# 5           2020.0                      2
# 6           2021.0                      1
# 7           2021.0                      1
# 8           2018.0                      1
# 9           2018.0                      1
# 10          2020.0                      1
# 11          2020.0                      1
# 12          2019.0                      2
# 13          2018.0                      2
# 14          2018.0                      2
# 15          2019.0                      3
# 16          2021.0                      1
# 17             NaN                      2
# 18          2021.0                      1
# 19          2020.0                      1
# 20          2020.0                      1
# 21          2019.0                      1
# 22          2018.0                      1
# 23          2019.0                      1
# 24          2020.0                      1
# 25          2019.0                      1
# 26          2021.0                      1
# 27          2018.0                      2
# 28          2018.0                      1

# %%
print(df_stud['math score'].quantile(0.10))
print(df_stud['math score'].quantile(0.90))
# Out:
# 61.8
# 79.0

# %%
df_stud1=df_stud.copy()
a= np.where(df_stud['math score']<62.0, 62.0,df_stud1['math score'])
b= np.where(df_stud['math score']<79.1, 79.1,df_stud1['math score'])

# %%
print("a=",a)
print("b=",b)
# Out:
# a= [65. 62. 64. 67. 68. 90. 79. 75. 62. 73. 74. 75. 65. 70. 62. 70. 63. 66.
#  94. 62. 67. 64. 62. 74. 79. 62. 67. 68. 72.]
# b= [79.1 79.1 79.1 79.1 79.1 90.  79.1 79.1 79.1 79.1 79.1 79.1 79.1 79.1
#  79.1 79.1 79.1 79.1 94.  79.1 79.1 79.1 79.1 79.1 79.1 79.1 79.1 79.1
#  79.1]

# %%
df_stud.insert(1,"new_math<62",a,True)
df_stud.insert(1,"new_math<79.1",b,True)
df_stud
# Out:
#     gender  new_math<79.1  new_math<62  math score  reading score  \
# 0        1           79.1         65.0          65           62.0
# 1        0           79.1         62.0          62           78.0
# 2        1           79.1         64.0          64           60.0
# 3        0           79.1         67.0          67           69.0
# 4        1           79.1         68.0          68           76.0
# 5        0           90.0         90.0          90           65.0
# 6        1           79.1         79.0          79           62.0
# 7        0           79.1         75.0          75           72.0
# 8        1           79.1         62.0          61           74.0
# 9        0           79.1         73.0          73           68.0
# 10       1           79.1         74.0          74           64.0
# 11       0           79.1         75.0          75           67.0
# 12       1           79.1         65.0          65           77.0
# 13       1           79.1         70.0          70           63.0
# 14       1           79.1         62.0          60           60.0
# 15       0           79.1         70.0          70           76.0
# 16       0           79.1         63.0          63           72.0
# 17       0           79.1         66.0          66           77.0
# 18       0           94.0         94.0          94           75.0
# 19       1           79.1         62.0          62           79.0
# 20       0           79.1         67.0          67           62.0
# 21       1           79.1         64.0          64           95.0
# 22       0           79.1         62.0          61           70.0
# 23       1           79.1         74.0          74           74.0
# 24       0           79.1         79.0          79           68.0
# 25       1           79.1         62.0          62           75.0
# 26       0           79.1         67.0          67           71.0
# 27       1           79.1         68.0          68           78.0
# 28       0           79.1         72.0          72           62.0
#
#     writing score  placement score  club join year  placement offer count
# 0              60             66.0          2018.0                      1
# 1              71             65.0          2018.0                      1
# 2              70             68.0          2020.0                      1
# 3              74             65.0          2021.0                      1
# 4              69             70.0          2019.0                      1
# 5              77             76.0          2020.0                      2
# 6              80             67.0          2021.0                      1
# 7              72             65.0          2021.0                      1
# 8              70             69.0          2018.0                      1
# 9              92             63.0          2018.0                      1
# 10             70             60.0          2020.0                      1
# 11             80             65.0          2020.0                      1
# 12             77             77.0          2019.0                      2
# 13             77             79.0          2018.0                      2
# 14             79             77.0          2018.0                      2
# 15             66             98.0          2019.0                      3
# 16             63             62.0          2021.0                      1
# 17             67             78.0             NaN                      2
# 18             67             66.0          2021.0                      1
# 19             68             60.0          2020.0                      1
# 20             64             61.0          2020.0                      1
# 21             72              NaN          2019.0                      1
# 22             96             72.0          2018.0                      1
# 23             75             68.0          2019.0                      1
# 24             75             67.0          2020.0                      1
# 25             60             69.0          2019.0                      1
# 26             72             64.0          2021.0                      1
# 27             64             77.0          2018.0                      2
# 28             77             69.0          2018.0                      1

# %% [markdown]
# ## **Imputing median value**

# %%
#col = ['reading score']
plt.boxplot(df['reading score'])
plt.show()

# %%
median=np.median(sorted_rscore)
median
# Out:
# 71.0

# %%
new_df=df.copy()
new_df2=new_df.copy()
new_df
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 0       M          65           62.0             60             66.0
# 1       F          62           78.0             71             65.0
# 2       M          64           60.0             70             68.0
# 3       F          67           69.0             74             65.0
# 4       M          68           76.0             69             70.0
# 5       F          90           65.0             77             76.0
# 6       M          79           62.0             80             67.0
# 7       F          75           72.0             72             65.0
# 8       M          61           74.0             70             69.0
# 9       F          73           68.0             92             63.0
# 10      M          74           64.0             70             60.0
# 11      F          75           67.0             80             65.0
# 12      M          65           77.0             77             77.0
# 13      M          70           63.0             77             79.0
# 14      M          60            NaN             79             77.0
# 15      F          70           76.0             66             98.0
# 16      F          63           72.0             63             62.0
# 17      F          66           77.0             67             78.0
# 18      F          94           75.0             67             66.0
# 19      M          62           79.0             68             60.0
# 20      F          67           62.0             64             61.0
# 21      M          64           95.0             72              NaN
# 22      F          61           70.0             96             72.0
# 23      M          74           74.0             75             68.0
# 24      F          79           68.0             75             67.0
# 25      M          62           75.0             60             69.0
# 26      F          67           71.0             72             64.0
# 27      M          68           78.0             64             77.0
# 28      F          72           62.0             77             69.0
#
#     club join year  placement offer count
# 0           2018.0                      1
# 1           2018.0                      1
# 2           2020.0                      1
# 3           2021.0                      1
# 4           2019.0                      1
# 5           2020.0                      2
# 6           2021.0                      1
# 7           2021.0                      1
# 8           2018.0                      1
# 9           2018.0                      1
# 10          2020.0                      1
# 11          2020.0                      1
# 12          2019.0                      2
# 13          2018.0                      2
# 14          2018.0                      2
# 15          2019.0                      3
# 16          2021.0                      1
# 17             NaN                      2
# 18          2021.0                      1
# 19          2020.0                      1
# 20          2020.0                      1
# 21          2019.0                      1
# 22          2018.0                      1
# 23          2019.0                      1
# 24          2020.0                      1
# 25          2019.0                      1
# 26          2021.0                      1
# 27          2018.0                      2
# 28          2018.0                      1

# %%
new_df['reading score']= np.where(new_df['reading score']>upr_bound,73.0,new_df['reading score'])

# %%
new_df.insert(2,"old_reading score",new_df2['reading score'],True)

# %%
new_df
# Out:
#    gender  math score  old_reading score  reading score  writing score  \
# 0       M          65               62.0           62.0             60
# 1       F          62               78.0           78.0             71
# 2       M          64               60.0           60.0             70
# 3       F          67               69.0           69.0             74
# 4       M          68               76.0           76.0             69
# 5       F          90               65.0           65.0             77
# 6       M          79               62.0           62.0             80
# 7       F          75               72.0           72.0             72
# 8       M          61               74.0           74.0             70
# 9       F          73               68.0           68.0             92
# 10      M          74               64.0           64.0             70
# 11      F          75               67.0           67.0             80
# 12      M          65               77.0           77.0             77
# 13      M          70               63.0           63.0             77
# 14      M          60                NaN            NaN             79
# 15      F          70               76.0           76.0             66
# 16      F          63               72.0           72.0             63
# 17      F          66               77.0           77.0             67
# 18      F          94               75.0           75.0             67
# 19      M          62               79.0           79.0             68
# 20      F          67               62.0           62.0             64
# 21      M          64               95.0           73.0             72
# 22      F          61               70.0           70.0             96
# 23      M          74               74.0           74.0             75
# 24      F          79               68.0           68.0             75
# 25      M          62               75.0           75.0             60
# 26      F          67               71.0           71.0             72
# 27      M          68               78.0           78.0             64
# 28      F          72               62.0           62.0             77
#
#     placement score  club join year  placement offer count
# 0              66.0          2018.0                      1
# 1              65.0          2018.0                      1
# 2              68.0          2020.0                      1
# 3              65.0          2021.0                      1
# 4              70.0          2019.0                      1
# 5              76.0          2020.0                      2
# 6              67.0          2021.0                      1
# 7              65.0          2021.0                      1
# 8              69.0          2018.0                      1
# 9              63.0          2018.0                      1
# 10             60.0          2020.0                      1
# 11             65.0          2020.0                      1
# 12             77.0          2019.0                      2
# 13             79.0          2018.0                      2
# 14             77.0          2018.0                      2
# 15             98.0          2019.0                      3
# 16             62.0          2021.0                      1
# 17             78.0             NaN                      2
# 18             66.0          2021.0                      1
# 19             60.0          2020.0                      1
# 20             61.0          2020.0                      1
# 21              NaN          2019.0                      1
# 22             72.0          2018.0                      1
# 23             68.0          2019.0                      1
# 24             67.0          2020.0                      1
# 25             69.0          2019.0                      1
# 26             64.0          2021.0                      1
# 27             77.0          2018.0                      2
# 28             69.0          2018.0                      1

# %%
plt.boxplot(new_df['reading score'])
plt.show()
